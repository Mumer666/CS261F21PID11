# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url ="https://www.pararius.com/apartments/haarlem"
page = requests.get(url)
soup = BeautifulSoup(page.content,'html.parser')
lists = soup.find_all('section' , class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','w',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    header=["university","name of Course","lectures videos","price of Course","students enrolled","name of professor","duration of course"]
    thewriter.writerow(header)
    for list in lists:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info)

# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url1 = "https://www.pararius.com/apartments/haarlem/page-2"
page1 = requests.get(url1)
soup1 = BeautifulSoup(page1.content, 'html.parser')
lists1 =soup1.find_all('section',class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','a',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    for list in lists1:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info1 = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info1)

# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url2 = "https://www.pararius.com/apartments/haarlem/page-3"
page2 = requests.get(url2)
soup2 = BeautifulSoup(page2.content, 'html.parser')
lists2 =soup2.find_all('section',class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','a',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    for list in lists2:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info2 = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info2)

# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url3 = "https://www.pararius.com/apartments/haarlem/page-4"
page3 = requests.get(url3)
soup3 = BeautifulSoup(page3.content, 'html.parser')
lists3 =soup3.find_all('section',class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','a',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    for list in lists3:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info3 = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info3)

# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url4 = "https://www.pararius.com/apartments/haarlem/page-5"
page4 = requests.get(url4)
soup4 = BeautifulSoup(page4.content, 'html.parser')
lists4 =soup4.find_all('section',class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','a',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    for list in lists4:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info4 = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info4)

# %%
from bs4 import BeautifulSoup
import requests
from csv import writer
url5 = "https://www.pararius.com/apartments/haarlem/page-6"
page5 = requests.get(url5)
soup5 = BeautifulSoup(page5.content, 'html.parser')
lists5 =soup5.find_all('section',class_="listing-search-item listing-search-item--list listing-search-item--for-rent")
with open('course.csv','a',encoding='utf8', newline='')as f:
    thewriter = writer(f)
    for list in lists5:
        name = list.find('a' ,'listing-search-item__link listing-search-item__link--title').text
        university = list.find('div' ,'listing-search-item__location').text.replace('\n','')
        price = list.find('div','listing-search-item__price').text.replace('\n','')
        lectures = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace('m²','lec videos')
        duration = list.find('li','illustrated-features__item illustrated-features__item--number-of-rooms').text.replace('rooms','months')
        students = list.find('li','illustrated-features__item illustrated-features__item--surface-area').text.replace(' ','').replace('m²','100')
        professor = list.find('div' ,'listing-search-item__info').text.replace('\n','')
        info5 = [university,name,lectures,price,students,professor,duration]
        thewriter.writerow(info5)
